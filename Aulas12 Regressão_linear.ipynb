# %%
# https://www.w3schools.com/python/python_ml_linear_regression.asp#:~:text=Linear%20regression%20uses%20the%20relationship,the%20future%20is%20very%20important.
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Modelo de regressão Linear simples

# %% [markdown]
# ## EXEMPLO 1

# %% [markdown]
# Podemos mudar os valores dos dados para verificar alterações no ajuste

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)
print("\n","Inclinação:", slope, "\n","Intercepto:",intercept, "\n","r-Pearson:",r, "\n", "p:",p, "\n", "std_error:",std_err)
# Out:
#  Inclinação: -1.751287711552612
#  Intercepto: 103.10596026490066
#  r-Pearson: -0.758591524376155
#  p: 0.0026468739224561064
#  std_error: 0.45353615760774213

# %%
def myfunc(x):
    return slope * x + intercept

#def f(x):
#    return b * x + a

mymodel = list(map(myfunc, x))
mymodel
# Out:
# [94.3495217071376,
#  90.84694628403237,
#  89.09565857247976,
#  90.84694628403237,
#  99.60338484179543,
#  73.33406916850626,
#  99.60338484179543,
#  87.34437086092716,
#  96.1008094186902,
#  83.84179543782193,
#  82.09050772626932,
#  87.34437086092716,
#  92.59823399558499]

# %%
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# ## EXEMPLO 2

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

rng = np.random.default_rng(42)
rng
# Out:
# Generator(PCG64) at 0x14A18E872E0

# %%
x = rng.random(100)
y = 1.6*x + rng.random(100)

# %%
x
# Out:
# array([0.75808774, 0.35452597, 0.97069802, 0.89312112, 0.7783835 ,
#        0.19463871, 0.466721  , 0.04380377, 0.15428949, 0.68304895,
#        0.74476216, 0.96750973, 0.32582536, 0.37045971, 0.46955581,
#        0.18947136, 0.12992151, 0.47570493, 0.22690935, 0.66981399,
#        0.43715192, 0.8326782 , 0.7002651 , 0.31236664, 0.8322598 ,
#        0.80476436, 0.38747838, 0.2883281 , 0.6824955 , 0.13975248,
#        0.1999082 , 0.00736227, 0.78692438, 0.66485086, 0.70516538,
#        0.78072903, 0.45891578, 0.5687412 , 0.139797  , 0.11453007,
#        0.66840296, 0.47109621, 0.56523611, 0.76499886, 0.63471832,
#        0.5535794 , 0.55920716, 0.3039501 , 0.03081783, 0.43671739,
#        0.21458467, 0.40852864, 0.85340307, 0.23393949, 0.05830274,
#        0.28138389, 0.29359376, 0.66191651, 0.55703215, 0.78389821,
#        0.66431354, 0.40638686, 0.81402038, 0.16697292, 0.02271207,
#        0.09004786, 0.72235935, 0.46187723, 0.16127178, 0.50104478,
#        0.1523121 , 0.69632038, 0.44615628, 0.38102123, 0.30151209,
#        0.63028259, 0.36181261, 0.08764992, 0.1180059 , 0.96189766,
#        0.90858069, 0.69970713, 0.26586996, 0.96917638, 0.7787509 ,
#        0.71689019, 0.4493615 , 0.27224156, 0.09639096, 0.9026024 ,
#        0.45577629, 0.20236336, 0.30595662, 0.57921957, 0.17677278,
#        0.85661428, 0.75851953, 0.71946296, 0.43209304, 0.62730884])

# %%
y
# Out:
# array([1.79703835, 1.21708815, 1.63756116, 1.8448012 , 1.28702777,
#        0.80541275, 1.07661482, 0.21461021, 0.35026616, 1.6805229 ,
#        1.36221242, 2.47313569, 1.10238171, 0.93960533, 1.34220479,
#        0.32595805, 1.16643362, 1.24343132, 1.14579019, 1.15443239,
#        1.1861014 , 1.82299211, 2.05825062, 1.07151468, 1.80510508,
#        1.55459864, 0.9515344 , 0.98199737, 1.53090427, 0.24521605,
#        1.14614505, 0.9079404 , 1.39932809, 1.61779751, 1.23684035,
#        1.92140654, 1.01549902, 1.56940855, 0.95066981, 0.95189561,
#        1.17718568, 1.66976577, 1.13459176, 1.26141073, 1.57040178,
#        1.25664932, 1.7245212 , 1.29457163, 0.36644743, 1.65164722,
#        0.63425331, 1.16870296, 1.62141001, 1.31034675, 0.2578922 ,
#        0.49512485, 0.90484707, 2.05144199, 1.78292871, 2.00284515,
#        1.95369416, 1.54366562, 1.82129098, 0.58308572, 0.80835175,
#        0.80573784, 1.52943269, 0.83347024, 1.00482446, 1.06413216,
#        1.18051251, 1.35508318, 0.83660797, 1.44074663, 0.63570366,
#        1.18772046, 1.17828297, 1.01480191, 0.38524411, 1.84935994,
#        2.23113394, 2.09135784, 0.92613312, 1.69457971, 1.25993773,
#        1.37668033, 0.85080062, 1.11324517, 0.27605804, 1.95049377,
#        1.4235045 , 0.90489799, 0.68930625, 1.73087584, 0.99824358,
#        2.10956686, 1.344689  , 1.27489453, 1.61891141, 1.40127234])

# %%
res = stats.linregress(x, y)

# %%
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.636815

# %%
res.intercept
# Out:
# 0.5596707595122513

# %%
res.slope
# Out:
# 1.441840946370307

# %%
plt.plot(x, y, 'o', label='original data')
plt.plot(x, res.intercept + res.slope*x, 'r', label='fitted line')
plt.legend()
plt.show()

# %% [markdown]
# # sklearn

# %%
from sklearn.linear_model import LinearRegression

import pandas as pd
from sklearn import preprocessing, svm

# %%
x_t = np.array(x).reshape(-1, 1)
y_t = np.array(y).reshape(-1, 1)
#x_t,y_t

# %%
regr = LinearRegression()

# %%
regr.fit(x_t, y_t)
# Out:
# LinearRegression()

# %%
y_pred = regr.predict(x_t)
#y_pred

# %% [markdown]
# R2, RMSE e MAE?

# %% [markdown]
# ## Erros
